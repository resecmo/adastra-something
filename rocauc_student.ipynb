# %%
# The script for plotting ROCAUC vs window size from lists of ROCAUCs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s = '''500         & 8     & 1     & 0.5088 $\pm$ 0.0012 \\\hline
1000        & 11    & 1     & 0.5081 $\pm$ 0.0022 \\\hline
2000        & 16    & 1     & 0.5096 $\pm$ 0.0020 \\\hline
4000        & 16    & 1     & 0.5076 $\pm$ 0.0012 \\\hline
8000        & 18    & 1     & 0.5073 $\pm$ 0.0021 \\\hline
16000       & 18    & 1     & 0.5087 $\pm$ 0.0029 \\\hline
32000       & 22    & 1     & 0.5075 $\pm$ 0.0024 \\\hline
64000       & 28    & 3     & 0.5121 $\pm$ 0.0021 \\\hline
128000      & 42    & 6     & 0.5212 $\pm$ 0.0042 \\\hline
256000      & 60    & 7     & 0.5221 $\pm$ 0.0026 \\\hline
512000      & 86    & 8     & 0.5217 $\pm$ 0.0025 \\\hline
1024000     & 159   & 13    & 0.5255 $\pm$ 0.0023 \\\hline
2048000     & 260   & 20    & 0.5276 $\pm$ 0.0038 \\\hline
4096000     & 399   & 25    & 0.5280 $\pm$ 0.0031 \\\hline
8192000     & 587   & 40    & 0.5424 $\pm$ 0.0055 \\\hline
16384000    & 842   & 57    & 0.5465 $\pm$ 0.0014 \\\hline'''.split('\n')
s = np.array([[float(i.split()[-4]), float(i.split()[-2])] for i in s])
means = s[:, 0]
sds = s[:, 1]
means, sds
# Out:
# (array([0.5088, 0.5081, 0.5096, 0.5076, 0.5073, 0.5087, 0.5075, 0.5121,
#         0.5212, 0.5221, 0.5217, 0.5255, 0.5276, 0.528 , 0.5424, 0.5465]),
#  array([0.0012, 0.0022, 0.002 , 0.0012, 0.0021, 0.0029, 0.0024, 0.0021,
#         0.0042, 0.0026, 0.0025, 0.0023, 0.0038, 0.0031, 0.0055, 0.0014]))

# %%
t = 2.571
n = 5
for i in range(len(means)):
    print(means[i], '+-', t * sds[i] / np.sqrt(n))
    
plt.figure(figsize=(12, 9))
plt.errorbar([f'{i:.1f}' for i in range(16)], s[:, 0], yerr=s[:, 1], ls='', fmt='s')
plt.xlabel('$\log_2$(window halfwidth / 500)', fontsize=16)
plt.ylabel('ROC AUC', fontsize=16)
plt.tight_layout()
plt.savefig('/home/resecmo/rocaucs.png')
# Out:
# 0.5088 +- 0.00137974338483647
# 0.5081 +- 0.0025295295388668626
# 0.5096 +- 0.002299572308060784
# 0.5076 +- 0.00137974338483647
# 0.5073 +- 0.002414550923463823
# 0.5087 +- 0.003334379846688136
# 0.5075 +- 0.00275948676967294
# 0.5121 +- 0.002414550923463823
# 0.5212 +- 0.004829101846927646
# 0.5221 +- 0.0029894440004790187
# 0.5217 +- 0.00287446538507598
# 0.5255 +- 0.0026445081542699014
# 0.5276 +- 0.004369187385315489
# 0.528 +- 0.003564337077494215
# 0.5424 +- 0.006323823847167155
# 0.5465 +- 0.0016097006156425486

# %%
rocaucs = {500: [0.51024448450299,
  0.5083827497428003,
  0.5059980634824423,
  0.5084643764018707,
  0.506666739853379,
  0.5098455053398403,
  0.5087760626086522,
  0.5121666279275827,
  0.5087246244523748,
  0.5071872867137134,
  0.5094054903009857,
  0.5077962751250676,
  0.5120795324503737,
  0.5065803919667511,
  0.5079497810761531,
  0.5059549772524987,
  0.5206652966744423,
  0.5319417110289283,
  0.5302034324416549,
  0.5219974233941408,
  0.5261214209186965,
  0.525076478828524,
  0.5275534818302063,
  0.5235422232271956,
  0.5242088855158105,
  0.5225865071265925,
  0.5255914971164947,
  0.5262628577481587,
  0.5198478257740137,
  0.5338174022553399,
  0.5201917184575987,
  0.529923664813219],
 4096000: [0.5243914239774411,
  0.5276524200021256,
  0.5257417034931438,
  0.529999203917063,
  0.5243198550629516,
  0.5235365770271525,
  0.5325330302840947,
  0.5199914379250129,
  0.5301551560019597,
  0.5341016537896253,
  0.5269708698136337,
  0.5301251074354667,
  0.5318476269194765,
  0.5268067575131197,
  0.5320477334766023,
  0.5250540404474313,
  0.5281304091489304,
  0.5306240379825591,
  0.5249494240599548,
  0.5293543848960336,
  0.5283646981690179,
  0.5278103149774188,
  0.5195821596584147,
  0.5281745271140129,
  0.5165985105038988],
 8192000: [0.5397721070701339,
  0.539450500897217,
  0.5406249100366589,
  0.5431943213280381,
  0.5359658182889391,
  0.5320503668280767,
  0.5414841612110708,
  0.5414013708301328,
  0.5349510931099245,
  0.546403568994596,
  0.5456404186765316,
  0.5447698865507392,
  0.5387020945629089,
  0.5442076382265321,
  0.5449696743012622,
  0.5402964797970664,
  0.5438954957651418,
  0.5458778129764867,
  0.5411934458504284,
  0.5434895823313697,
  0.5390346053336099,
  0.5413821863622184,
  0.5375944340588088,
  0.5426221373505905,
  0.5390654282982116],
 16384000: [0.5442448647124931,
  0.544503585489511,
  0.5414088646744849,
  0.5461198985725998,
  0.5521632970192641,
  0.5492958305931233,
  0.5431041617813716,
  0.5468973999278449,
  0.5496842003051332,
  0.5389012256214724,
  0.5503290131005854,
  0.5482142924640222,
  0.5479042562612809,
  0.5475582536050869,
  0.5390322988645403,
  0.5415743905122704,
  0.5458709299672821,
  0.5466922030559611,
  0.5415727561805577,
  0.538632477967022,
  0.5421158238484909,
  0.5453726855913763,
  0.5433035290637063,
  0.5504095223653597,
  0.5444400650994723]}

# %%
means = np.array([np.mean(i) for _, i in rocaucs.items()])
sds = np.array([np.std(i, ddof=1) for _, i in rocaucs.items()])
means, sds

t = 2.060
n = 25
for i in range(len(means)):
    print(f'{means[i]:.4f} $\\pm$ {t * sds[i] / np.sqrt(n):.4f}')
    
plt.figure(figsize=(12, 9))
plt.errorbar([f'{i:.1f}' for i in range(16)], means, yerr=(t * sds / np.sqrt(n)), ls='', fmt='s')
plt.xlabel('$\log_2$(window halfwidth / 500)', fontsize=16)
plt.ylabel('ROC AUC', fontsize=16)
plt.tight_layout()
plt.savefig('rocaucs.png')
# Out:
# 0.5087 $\pm$ 0.0009
# 0.5077 $\pm$ 0.0008
# 0.5082 $\pm$ 0.0010
# 0.5082 $\pm$ 0.0008
# 0.5080 $\pm$ 0.0011
# 0.5075 $\pm$ 0.0009
# 0.5078 $\pm$ 0.0009
# 0.5123 $\pm$ 0.0017
# 0.5218 $\pm$ 0.0012
# 0.5235 $\pm$ 0.0012
# 0.5226 $\pm$ 0.0015
# 0.5252 $\pm$ 0.0014
# 0.5255 $\pm$ 0.0017
# 0.5272 $\pm$ 0.0017
# 0.5411 $\pm$ 0.0015
# 0.5452 $\pm$ 0.0016
